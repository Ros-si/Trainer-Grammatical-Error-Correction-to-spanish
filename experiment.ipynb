# %%
# !nvidia-smi
# Out:
# Tue Apr  7 14:05:04 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install transformers[torch] datasets accelerate wandb -U -qqq
# !pip install sentencepiece sacrebleu rouge_score -qqq

# %%
import torch
print(f"¿GPU disponible?: {torch.cuda.is_available()}")
print(f"Nombre de la GPU: {torch.cuda.get_device_name(0)}")
# Out:
# ¿GPU disponible?: True
# Nombre de la GPU: Tesla T4

# %%
# !ls
# Out:
# sample_data

# %%
# !ls
# Out:
# sample_data

# %%
# !git clone https://github.com/Ros-si/Trainer-Grammatical-Error-Correction-to-spanish.git
# Out:
# Cloning into 'Trainer-Grammatical-Error-Correction-to-spanish'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 26 (delta 1), reused 26 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 12.26 KiB | 6.13 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !ls Trainer-Grammatical-Error-Correction-to-spanish/
# Out:
# app.py	experiment.ipynb  main.py  requirements.txt  setup.py  src

# %%
# !python Trainer-Grammatical-Error-Correction-to-spanish/main.py
# Out:
# 2026-04-07 14:50:48.904975: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775573448.944315   11489 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775573448.954983   11489 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775573448.980430   11489 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls Trainer-Grammatical-Error-Correction-to-spanish
# !!
